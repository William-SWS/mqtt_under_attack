# %%
import pandas as pd


df = pd.read_csv("iinference_rasp.csv")

df.sort_values("inference_time_ms", ascending=True).reset_index(drop=True)
# Out:
#                        model_id  \
# 0               lowvariance_lda
# 1      lowvariance_decisiontree
# 2  lowvariance_gradientboosting
# 3   extratrees_gradientboosting
# 4      lowvariance_randomforest
#
#                                           model_file  \
# 0             optuna_by_selector_lowvariance_lda.pkl
# 1    optuna_by_selector_lowvariance_decisiontree.pkl
# 2  optuna_by_selector_lowvariance_gradientboostin...
# 3  optuna_by_selector_extratrees_gradientboosting...
# 4    optuna_by_selector_lowvariance_randomforest.pkl
#
#                                         dataset_file   rows  n_features  \
# 0        test_optuna_by_selector_lowvariance_lda.csv  18925          12
# 1  test_optuna_by_selector_lowvariance_decisiontr...  18925          12
# 2  test_optuna_by_selector_lowvariance_gradientbo...  18925          12
# 3  test_optuna_by_selector_extratrees_gradientboo...  18925          15
# 4  test_optuna_by_selector_lowvariance_randomfore...  18925          12
#
#    load_time_sec  dataset_read_time_sec  inference_time_sec  \
# 0       0.002108               0.138250            0.006242
# 1       0.002214               0.056040            0.008410
# 2       0.025971               0.055453            0.168183
# 3       0.028581               0.064058            0.171845
# 4       0.214434               0.056249            0.586827
#
#    inference_time_ms  avg_inference_ms_per_row  predictions_per_sec  accuracy  \
# 0           6.241963                  0.000330         3.031899e+06  0.923857
# 1           8.409778                  0.000444         2.250357e+06  0.968824
# 2         168.183370                  0.008887         1.125260e+05  0.975376
# 3         171.844870                  0.009080         1.101284e+05  0.975376
# 4         586.826648                  0.031008         3.224973e+04  0.973474
#
#     status  error                        created_at
# 0  success    NaN  2026-06-03T20:25:38.852317+00:00
# 1  success    NaN  2026-06-03T20:25:37.774133+00:00
# 2  success    NaN  2026-06-03T20:25:38.219653+00:00
# 3  success    NaN  2026-06-03T20:25:37.107711+00:00
# 4  success    NaN  2026-06-03T20:25:39.400028+00:00
