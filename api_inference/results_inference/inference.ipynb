# %%
import pandas as pd 
from pathlib import Path

base = Path("api_inference/results_inference")
candidates = [
    base / "iinference.csv",
    base / "inference.csv",
]
csv_path = None

if base.exists():
    for p in candidates:
        if p.exists():
            csv_path = p
            break
    if csv_path is None:
        files = sorted(base.glob("*.csv"))
        if files:
            csv_path = files[0]
else:
    matches = list(Path(".").rglob("*inference*.csv"))
    if matches:
        csv_path = matches[0]

if csv_path is None:
    raise FileNotFoundError(
        "CSV not found. Checked: 'api_inference/results_inference/iinference.csv', "
        "'api_inference/results_inference/inference.csv', directory CSVs, and recursive search."
    )

df = pd.read_csv(csv_path)
df.head(10)
# Out:
#                        model_id  \
# 0   extratrees_gradientboosting
# 1      lowvariance_decisiontree
# 2  lowvariance_gradientboosting
# 3               lowvariance_lda
# 4      lowvariance_randomforest
#
#                                           model_file  \
# 0  optuna_by_selector_extratrees_gradientboosting...
# 1    optuna_by_selector_lowvariance_decisiontree.pkl
# 2  optuna_by_selector_lowvariance_gradientboostin...
# 3             optuna_by_selector_lowvariance_lda.pkl
# 4    optuna_by_selector_lowvariance_randomforest.pkl
#
#                                         dataset_file   rows  n_features  \
# 0  test_optuna_by_selector_extratrees_gradientboo...  18925          15
# 1  test_optuna_by_selector_lowvariance_decisiontr...  18925          12
# 2  test_optuna_by_selector_lowvariance_gradientbo...  18925          12
# 3        test_optuna_by_selector_lowvariance_lda.csv  18925          12
# 4  test_optuna_by_selector_lowvariance_randomfore...  18925          12
#
#    load_time_sec  dataset_read_time_sec  inference_time_sec  \
# 0       0.002356               0.008329            0.043894
# 1       0.000299               0.007381            0.001069
# 2       0.002374               0.007081            0.042567
# 3       0.000270               0.017600            0.000581
# 4       0.020008               0.006974            0.112259
#
#    inference_time_ms  avg_inference_ms_per_row  predictions_per_sec  accuracy  \
# 0          43.893735                  0.002319         4.311549e+05  0.975376
# 1           1.069210                  0.000056         1.769998e+07  0.968824
# 2          42.566591                  0.002249         4.445975e+05  0.975376
# 3           0.580767                  0.000031         3.258622e+07  0.923857
# 4         112.259256                  0.005932         1.685830e+05  0.973474
#
#     status  error                        created_at
# 0  success    NaN  2026-06-03T12:51:23.969595+00:00
# 1  success    NaN  2026-06-03T12:51:24.064943+00:00
# 2  success    NaN  2026-06-03T12:51:24.115702+00:00
# 3  success    NaN  2026-06-03T12:51:24.207632+00:00
# 4  success    NaN  2026-06-03T12:51:24.266647+00:00
