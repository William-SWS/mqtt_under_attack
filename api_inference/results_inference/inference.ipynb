# %%
import pandas as pd


df = pd.read_csv("iinference.csv")

df.sort_values("inference_time_ms", ascending=True).reset_index(drop=True)
# Out:
#                          model_id  \
# 0                     lassocv_lda
# 1                      fisher_lda
# 2                linearsvc_l1_lda
# 3                        mrmr_lda
# 4                  extratrees_lda
# 5                     pearson_lda
# 6                 lowvariance_lda
# 7        lowvariance_decisiontree
# 8       linearsvc_l1_decisiontree
# 9            lassocv_decisiontree
# 10            fisher_decisiontree
# 11              mrmr_decisiontree
# 12        extratrees_decisiontree
# 13           pearson_decisiontree
# 14         lowvariance_gaussiannb
# 15        linearsvc_l1_gaussiannb
# 16             pearson_gaussiannb
# 17             lassocv_gaussiannb
# 18              fisher_gaussiannb
# 19                mrmr_gaussiannb
# 20                lowvariance_qda
# 21          extratrees_gaussiannb
# 22               linearsvc_l1_qda
# 23                    lassocv_qda
# 24                     fisher_qda
# 25                 extratrees_qda
# ...
