# %%
import pandas as pd
from pathlib import Path
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
intrusion_path = Path("/home/william/Projetos/mqtt_under_attack/data/raw/MQTT Under Attack Dataset/Intrusion.csv")
df = pd.read_csv(intrusion_path)

df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 intrusion_path = Path("C:/Projetos/mqtt_under_attack/data/raw/MQTT Under Attack Dataset/Intrusion.csv")
# ----> 2 df = pd.read_csv(intrusion_path)
#       4 df.info()
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.describe()
# Out:
#        frame.time_delta  frame.time_delta_displayed  frame.time_epoch  \
# count      80893.000000                80893.000000      8.089300e+04
# mean           0.063848                    0.063848      1.535975e+09
# std            0.304836                    0.304836      1.473447e+03
# min            0.000000                    0.000000      1.535972e+09
# 25%            0.000105                    0.000105      1.535974e+09
# 50%            0.000663                    0.000663      1.535975e+09
# 75%            0.005465                    0.005465      1.535977e+09
# max            8.383077                    8.383077      1.535977e+09
#
#        frame.time_invalid  frame.time_relative   tcp.srcport   tcp.dstport  \
# count                 0.0         80893.000000  71757.000000  71757.000000
# mean                  NaN          3191.640346  25475.912078  26835.512229
# std                   NaN          1473.447135  25532.825179  25548.302062
# ...

# %% [markdown]
# ### Mostrando todas as colunas do dataset

# %%
pd.set_option('display.max_columns', None)
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 pd.set_option('display.max_columns', None)
# ----> 2 print(df.columns)
#
# NameError: name 'df' is not defined
