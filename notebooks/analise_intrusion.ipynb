# %%
import pandas as pd
from pathlib import Path
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
intrusion_path = Path("/home/william/Projetos/mqtt_under_attack/data/raw/MQTT Under Attack Dataset/Intrusion.csv")
df = pd.read_csv(intrusion_path)

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 80893 entries, 0 to 80892
# Data columns (total 67 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   frame.time_delta            80893 non-null  float64
#  1   frame.time_delta_displayed  80893 non-null  float64
#  2   frame.time_epoch            80893 non-null  float64
#  3   frame.time_invalid          0 non-null      float64
#  4   frame.time_relative         80893 non-null  float64
#  5   ip.src                      77106 non-null  str
#  6   ip.dst                      77106 non-null  str
#  7   tcp.srcport                 71757 non-null  float64
#  8   tcp.dstport                 71757 non-null  float64
#  9   eth.src                     80893 non-null  str
#  10  eth.dst                     80893 non-null  str
#  11  frame.cap_len               80893 non-null  int64
#  12  frame.coloring_rule.name    0 non-null      float64
# ...

# %%
df.describe()
# Out:
#        frame.time_delta  frame.time_delta_displayed  frame.time_epoch  \
# count      80893.000000                80893.000000      8.089300e+04
# mean           0.063848                    0.063848      1.535975e+09
# std            0.304836                    0.304836      1.473447e+03
# min            0.000000                    0.000000      1.535972e+09
# 25%            0.000105                    0.000105      1.535974e+09
# 50%            0.000663                    0.000663      1.535975e+09
# 75%            0.005465                    0.005465      1.535977e+09
# max            8.383077                    8.383077      1.535977e+09
#
#        frame.time_invalid  frame.time_relative   tcp.srcport   tcp.dstport  \
# count                 0.0         80893.000000  71757.000000  71757.000000
# mean                  NaN          3191.640346  25475.912078  26835.512229
# std                   NaN          1473.447135  25532.825179  25548.302062
# ...

# %% [markdown]
# ### Mostrando todas as colunas do dataset

# %%
pd.set_option('display.max_columns', None)
print(df.columns)
# Out:
# Index(['frame.time_delta', 'frame.time_delta_displayed', 'frame.time_epoch',
#        'frame.time_invalid', 'frame.time_relative', 'ip.src', 'ip.dst',
#        'tcp.srcport', 'tcp.dstport', 'eth.src', 'eth.dst', 'frame.cap_len',
#        'frame.coloring_rule.name', 'frame.coloring_rule.string',
#        'frame.comment', 'frame.comment.expert', 'frame.encap_type',
#        'frame.file_off', 'frame.ignored', 'frame.incomplete',
#        'frame.interface_id', 'frame.interface_name', 'frame.len',
#        'frame.link_nr', 'frame.marked', 'frame.md5_hash', 'frame.number',
#        'frame.offset_shift', 'mqtt.clientid', 'mqtt.clientid_len',
#        'mqtt.conack.flags', 'mqtt.conack.flags.reserved',
#        'mqtt.conack.flags.sp', 'mqtt.conack.val', 'mqtt.conflag.cleansess',
#        'mqtt.conflag.passwd', 'mqtt.conflag.qos', 'mqtt.conflag.reserved',
#        'mqtt.conflag.retain', 'mqtt.conflag.uname', 'mqtt.conflag.willflag',
# ...

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
df.describe(include="all")
# Out:
#         frame.time_delta  frame.time_delta_displayed  frame.time_epoch  \
# count       80893.000000                80893.000000      8.089300e+04
# unique               NaN                         NaN               NaN
# top                  NaN                         NaN               NaN
# freq                 NaN                         NaN               NaN
# mean            0.063848                    0.063848      1.535975e+09
# std             0.304836                    0.304836      1.473447e+03
# min             0.000000                    0.000000      1.535972e+09
# 25%             0.000105                    0.000105      1.535974e+09
# 50%             0.000663                    0.000663      1.535975e+09
# 75%             0.005465                    0.005465      1.535977e+09
# max             8.383077                    8.383077      1.535977e+09
#
#         frame.time_invalid  frame.time_relative         ip.src         ip.dst  \
# ...

# %% [markdown]
# ### Pegando apenas as colunas numéricas

# %%
df = df.select_dtypes(include = ["int64" , "float"])
pd.set_option('display.max_columns' , None)
print(df.columns)
qt_columnas = df.shape[1]
print("Quantidade de colunas do dataset com apenas as features numéricas: " , qt_columnas)
# Out:
# Index(['frame.time_delta', 'frame.time_delta_displayed', 'frame.time_epoch',
#        'frame.time_invalid', 'frame.time_relative', 'tcp.srcport',
#        'tcp.dstport', 'frame.cap_len', 'frame.coloring_rule.name',
#        'frame.coloring_rule.string', 'frame.comment', 'frame.comment.expert',
#        'frame.encap_type', 'frame.file_off', 'frame.ignored',
#        'frame.incomplete', 'frame.interface_id', 'frame.interface_name',
#        'frame.len', 'frame.link_nr', 'frame.marked', 'frame.md5_hash',
#        'frame.number', 'frame.offset_shift', 'mqtt.clientid_len',
#        'mqtt.conack.flags.reserved', 'mqtt.conack.flags.sp', 'mqtt.conack.val',
#        'mqtt.conflag.cleansess', 'mqtt.conflag.passwd', 'mqtt.conflag.qos',
#        'mqtt.conflag.reserved', 'mqtt.conflag.retain', 'mqtt.conflag.uname',
#        'mqtt.conflag.willflag', 'mqtt.dupflag', 'mqtt.kalive', 'mqtt.len',
#        'mqtt.msg', 'mqtt.msgid', 'mqtt.msgtype', 'mqtt.passwd',
# ...

# %% [markdown]
# ### Configurar o pandas para não ter limite na visualização

# %%
pd.set_option('display.max_rows', None)
print(df.dtypes)
# Out:
# frame.time_delta              float64
# frame.time_delta_displayed    float64
# frame.time_epoch              float64
# frame.time_invalid            float64
# frame.time_relative           float64
# tcp.srcport                   float64
# tcp.dstport                   float64
# frame.cap_len                   int64
# frame.coloring_rule.name      float64
# frame.coloring_rule.string    float64
# frame.comment                 float64
# frame.comment.expert          float64
# frame.encap_type                int64
# frame.file_off                float64
# frame.ignored                   int64
# frame.incomplete              float64
# frame.interface_id            float64
# frame.interface_name          float64
# frame.len                       int64
# frame.link_nr                 float64
# frame.marked                    int64
# frame.md5_hash                float64
# frame.number                    int64
# frame.offset_shift            float64
# mqtt.clientid_len             float64
# ...

# %%
# Destrava o limite de linhas (altura)
pd.set_option('display.max_rows', None)

# Destrava o limite de colunas (largura)
pd.set_option('display.max_columns', None)

# Destrava o limite de largura do texto (para não quebrar linhas)
pd.set_option('display.width', None)

print(df.dtypes)
# Out:
# frame.time_delta              float64
# frame.time_delta_displayed    float64
# frame.time_epoch              float64
# frame.time_invalid            float64
# frame.time_relative           float64
# tcp.srcport                   float64
# tcp.dstport                   float64
# frame.cap_len                   int64
# frame.coloring_rule.name      float64
# frame.coloring_rule.string    float64
# frame.comment                 float64
# frame.comment.expert          float64
# frame.encap_type                int64
# frame.file_off                float64
# frame.ignored                   int64
# frame.incomplete              float64
# frame.interface_id            float64
# frame.interface_name          float64
# frame.len                       int64
# frame.link_nr                 float64
# frame.marked                    int64
# frame.md5_hash                float64
# frame.number                    int64
# frame.offset_shift            float64
# mqtt.clientid_len             float64
# ...

# %%
# Destrava o limite de linhas (altura)
pd.set_option('display.max_rows', None)

# Destrava o limite de colunas (largura)
pd.set_option('display.max_columns', None)

# Destrava o limite de largura do texto (para não quebrar linhas)
pd.set_option('display.width', None)

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 80893 entries, 0 to 80892
# Data columns (total 56 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   frame.time_delta            80893 non-null  float64
#  1   frame.time_delta_displayed  80893 non-null  float64
#  2   frame.time_epoch            80893 non-null  float64
#  3   frame.time_invalid          0 non-null      float64
#  4   frame.time_relative         80893 non-null  float64
#  5   tcp.srcport                 71757 non-null  float64
#  6   tcp.dstport                 71757 non-null  float64
#  7   frame.cap_len               80893 non-null  int64
#  8   frame.coloring_rule.name    0 non-null      float64
#  9   frame.coloring_rule.string  0 non-null      float64
#  10  frame.comment               0 non-null      float64
#  11  frame.comment.expert        0 non-null      float64
#  12  frame.encap_type            80893 non-null  int64
# ...

# %%
print(df.columns)
# Out:
# Index(['frame.time_delta', 'frame.time_delta_displayed', 'frame.time_epoch',
#        'frame.time_invalid', 'frame.time_relative', 'tcp.srcport',
#        'tcp.dstport', 'frame.cap_len', 'frame.coloring_rule.name',
#        'frame.coloring_rule.string', 'frame.comment', 'frame.comment.expert',
#        'frame.encap_type', 'frame.file_off', 'frame.ignored',
#        'frame.incomplete', 'frame.interface_id', 'frame.interface_name',
#        'frame.len', 'frame.link_nr', 'frame.marked', 'frame.md5_hash',
#        'frame.number', 'frame.offset_shift', 'mqtt.clientid_len',
#        'mqtt.conack.flags.reserved', 'mqtt.conack.flags.sp', 'mqtt.conack.val',
#        'mqtt.conflag.cleansess', 'mqtt.conflag.passwd', 'mqtt.conflag.qos',
#        'mqtt.conflag.reserved', 'mqtt.conflag.retain', 'mqtt.conflag.uname',
#        'mqtt.conflag.willflag', 'mqtt.dupflag', 'mqtt.kalive', 'mqtt.len',
#        'mqtt.msg', 'mqtt.msgid', 'mqtt.msgtype', 'mqtt.passwd',
# ...
